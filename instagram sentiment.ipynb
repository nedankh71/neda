# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import torch
import transformers

# %%
df = pd.read_csv('Instagram.csv', usecols=['reviewId', 'content', 'score'])
df.head()
# Out:
#                                reviewId  \
# 0  cd74b152-a414-4130-bfef-840bc40c10ce
# 1  dda755b1-49aa-49be-be9f-32a04297fd52
# 2  37f5c7c7-1af4-4d37-9e7b-64bd84a802df
# 3  a914568e-a2b3-401a-a532-d0309de193f0
# 4  a5adc8ad-7f14-4c79-9e16-5fbf5df30da8
#
#                                              content  score
# 0  another update, still nothing's fixed. Can't p...      1
# 1  Bull.sh.it App, my Videos are not getting any ...      1
# 2                                               Good      5
# 3  This Caption looks similar that been Reported ...      1
# 4                                       It's garbage      1

# %%
df= df.sample(200)
df
# Out:
#                                   reviewId  \
# 525   f7c1de42-7ee8-4cd8-8911-3daaed825e63
# 978   99e4e704-67d4-4882-8db4-016d8fbd2cd5
# 1581  9bc69256-26ac-49bf-92cc-5bb098ca26bf
# 1273  b4a8335f-1aca-4a3a-9d8e-291866e4e7e4
# 2907  0fd058c3-c1d0-4228-8472-85a3539e3656
# ...                                    ...
# 2466  81974578-0d0b-4fe1-8bc8-c10b622b026b
# 1858  6caa35ed-d989-4f9d-843b-2b1c9aeb2910
# 1515  419132b8-6bb2-4328-88b8-005ec4fedd15
# 9195  0f76c207-ae15-4ad6-84dd-f0d7144a9c0b
# 9844  c6bb050c-8f6c-429e-baf7-1a9825ca1b7a
#
#                                                 content  score
# 525                                             Love it      5
# 978                                               Supar      5
# 1581        It is full of life and makes me feel better      5
# 1273                                           Best aap      5
# 2907                                      Good platform      5
# ...                                                 ...    ...
# 2466                                 Best reel in video      4
# 1858                                         👍👍👍👍🙏🙏🙏🙏🙏🙏      5
# 1515  It good, but I don't get more followers and en...      5
# 9195                                                🫶❣️      5
# 9844  Every time we get to a version that works, you...      2
#
# [200 rows x 3 columns]

# %%
from transformers import pipeline
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer

tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased-finetuned-sst-2-english')
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased-finetuned-sst-2-english')

nlp = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

text = list(df.content.values)
result = nlp(text)
# Out:
# Device set to use cpu

# %%
for text, res, score in zip(text, result, df.content.values):
    print('text:', text)
    print('result:', text)
    print('score:', text)
# Out:
# text: !
# result: !
# score: !

# %%
df['sentiment'] = [r['label'] for r in result]
df.head(50)
# Out:
#                                   reviewId  \
# 525   f7c1de42-7ee8-4cd8-8911-3daaed825e63
# 978   99e4e704-67d4-4882-8db4-016d8fbd2cd5
# 1581  9bc69256-26ac-49bf-92cc-5bb098ca26bf
# 1273  b4a8335f-1aca-4a3a-9d8e-291866e4e7e4
# 3427  72eeb5b2-6912-448c-8e3d-0c80e37152d9
# 674   35ae0b65-6311-440c-80da-bce6d7503783
# 8784  79592507-6763-4b91-92e4-fcb4d4e91d0f
#
#                                                 content  score sentiment
# 525                                             Love it      5  POSITIVE
# 978                                               Supar      5  POSITIVE
# 1581        It is full of life and makes me feel better      5  POSITIVE
# 1273                                           Best aap      5  POSITIVE
# 2907                                      Good platform      5  POSITIVE
# 8028  hlo insta team mere phone me insta load krte h...      1  NEGATIVE
# 1808                                                ☠️🤫      4  NEGATIVE
# 2864                                              عالیه      5  POSITIVE
# 9332                           Superb and amazing 💜💜💜💜💜      5  POSITIVE
# 1071              My Instagram doesn't want to download      1  NEGATIVE
# 22    That account suggestion on the instagram story...      1  NEGATIVE
# 1955                                  Satya raj rajpoot      5  POSITIVE
# 9137                                    Krushna ❤️ dada      3  NEGATIVE
# 8748  Can u fix the bug on android when posting coll...      3  NEGATIVE
# 1843                                                  😎      5  NEGATIVE
# 6912                                              Super      5  POSITIVE
# 6273        काय फायदा इंस्ता घेऊन कोणी पटत नाही भावांनो      5  NEGATIVE
# 1637                                               Good      5  POSITIVE
# 3223                                     It is best app      5  POSITIVE
# 7272  No issues list showing in help center . They c...      1  NEGATIVE
# 7364                                          Hedar app      1  NEGATIVE
# 8839                                 Shamaun sortha 302      2  NEGATIVE
# 5248                                               good      5  POSITIVE
# 8135                                        Not a bad 😞      5  POSITIVE
# 4537                                               Nice      5  POSITIVE
# 4581                        Amazing Short entertainment      5  POSITIVE
# 6756                                          I like it      5  POSITIVE
# 8275                                              👈🏻🤡👉🏻      5  NEGATIVE
# 3122                                           Super 💪💪      5  POSITIVE
# 6288                                      Luqman A seif      1  NEGATIVE
# 7668  Now I can finally rate Instagram with 5 ⭐. Now...      5  NEGATIVE
# 7972                    This app is great and amazing!!      5  POSITIVE
# 515                                         So good app      5  POSITIVE
# 13                                              Superr.      5  POSITIVE
# 9573                                               Good      5  POSITIVE
# 7979                                          Very nice      5  POSITIVE
# 6668                                               Good      5  POSITIVE
# 6972                                         Its good 😊      5  POSITIVE
# 6651                                        Yeri Nice 👍      2  POSITIVE
# 1456                                             great!      5  POSITIVE
# 8191                                           Best aap      5  POSITIVE
# 7654                          Great for business owners      5  POSITIVE
# 5988                                         كسم السيسي      1  POSITIVE
# 5226                  Best Social Media ever . Loved it      4  POSITIVE
# 344                  Bekar aap hai ladki nhi Patata hai      5  POSITIVE
# 7193                        very poor need to improve 😑      1  NEGATIVE
# 9854                                           LOLA APP      1  POSITIVE
# 3427  I love the instagram I hope they won't block m...      5  POSITIVE
# 674   Theviyaa payan da niga oru rotate ava matingit...      1  NEGATIVE
# 8784                                                Utj      5  POSITIVE
